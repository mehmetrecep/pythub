# %%
from data_preprocessing_lib import (
    MissingValueHandler, 
    OutlierHandler, 
    Scaler, 
    TextCleaner, 
    FeatureEngineer, 
    DataTypeConverter, 
    CategoricalEncoder, 
    DateTimeHandler, 
    DataFrameLoader
)
import pandas as pd

data = DataFrameLoader.read_csv('airlines.csv')
daf = pd.DataFrame(data)
daf
# Out:
#       Airline ID                                          Name  \
# 0             -1                                       Unknown
# 1              1                                Private flight
# 2              2                                   135 Airways
# 3              3                                 1Time Airline
# 4              4  2 Sqn No 1 Elementary Flying Training School
# ...          ...                                           ...
# 6157       21248                                   GX Airlines
# 6158       21251                        Lynx Aviation (L3/SSX)
# 6159       21268                               Jetgo Australia
# 6160       21270                                  Air Carnival
# 6161       21317                                 Svyaz Rossiya
#
#                   Alias IATA ICAO         Callsign         Country Active
# 0                    \N    -  NaN               \N              \N      Y
# 1                    \N    -  NaN              NaN             NaN      Y
# 2                    \N  NaN  GNL          GENERAL   United States      N
# 3                    \N   1T  RNX          NEXTIME    South Africa      Y
# 4                    \N  NaN  WYT              NaN  United Kingdom      N
# ...                 ...  ...  ...              ...             ...    ...
# 6157                NaN  NaN  CBG            SPRAY           China      Y
# 6158                NaN  NaN  SSX           Shasta   United States      N
# 6159                NaN   JG   \N              NaN       Australia      Y
# 6160                NaN   2S   \N              NaN           India      Y
# 6161  Russian Commuter    7R  SJM  RussianConnecty          Russia      Y
#
# [6162 rows x 8 columns]

# %%
data_1 = ms.MissingValueHandler.delete_missing(data, columns=['Country'])
data_1 = ms.MissingValueHandler.replace_value(data,value = ':)')
#data_2 = dt.DateTimeHandler.to_datetime(df, columns='date')
data_1
# Out:
#       Airline ID                                          Name  \
# 0             -1                                       Unknown
# 1              1                                Private flight
# 2              2                                   135 Airways
# 3              3                                 1Time Airline
# 4              4  2 Sqn No 1 Elementary Flying Training School
# ...          ...                                           ...
# 6157       21248                                   GX Airlines
# 6158       21251                        Lynx Aviation (L3/SSX)
# 6159       21268                               Jetgo Australia
# 6160       21270                                  Air Carnival
# 6161       21317                                 Svyaz Rossiya
#
#                   Alias IATA ICAO         Callsign         Country Active
# 0                    :)    -   :)               :)              :)      Y
# 1                    :)    -   :)               :)              :)      Y
# 2                    :)   :)  GNL          GENERAL   United States      N
# 3                    :)   1T  RNX          NEXTIME    South Africa      Y
# 4                    :)   :)  WYT               :)  United Kingdom      N
# ...                 ...  ...  ...              ...             ...    ...
# 6157                 :)   :)  CBG            SPRAY           China      Y
# 6158                 :)   :)  SSX           Shasta   United States      N
# 6159                 :)   JG   :)               :)       Australia      Y
# 6160                 :)   2S   :)               :)           India      Y
# 6161  Russian Commuter    7R  SJM  RussianConnecty          Russia      Y
#
# [6162 rows x 8 columns]

# %%
import pandas as pd
from data_preprocessing_lib import MissingValueHandler

# Sample DataFrame
data = {
    'A': [1, 2, None, 4],
    'B': [None, 2, 3, None],
    'C': [1, None, None, 4]
}
df = pd.DataFrame(data)

# Impute missing values with the mean
df = MissingValueHandler.MissingValueHandler.delete_missing(df, ['A', 'B'])
df
# Out:
#      A    B   C
# 1  2.0  2.0 NaN

# %%
# Out:
# /Users/moustafa/PycharmProjects/pythub/data_preprocessing_lib/missing_value_handler.py:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return df.replace(missing_values, value)
#    A  B  C
# 0  1  5  0
# 1  2  0  b
# 2  0  7  0
# 3  4  8  d
# 4  0  0  0
# 5  0  0  0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 17
#      14 print(df_replaced)
#      16 # Impute missing values with mean in columns 'A' and 'B'
# ---> 17 df_imputed_mean = MissingValueHandler.impute_mean(df, columns=['A', 'B'])
#      18 print(df_imputed_mean)
#      20 # Impute missing values with median in columns 'A' and 'B'
#
# File ~/PycharmProjects/pythub/data_preprocessing_lib/missing_value_handler.py:34, in MissingValueHandler.impute_mean(df, columns)
#      23 """
#      24 Impute missing values in specified columns with the mean of the column.
#      25
#    (...)
#      31 pd.DataFrame: The DataFrame with imputed values.
#      32 """
#      33 for col in columns:
# ---> 34     df[col].fillna(df[col].mean(), inplace=True)
#      35 return df
#
# File ~/PycharmProjects/pythub/.venv/lib/python3.10/site-packages/pandas/core/series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/PycharmProjects/pythub/.venv/lib/python3.10/site-packages/pandas/core/generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File ~/PycharmProjects/pythub/.venv/lib/python3.10/site-packages/pandas/core/generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File ~/PycharmProjects/pythub/.venv/lib/python3.10/site-packages/pandas/core/series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File ~/PycharmProjects/pythub/.venv/lib/python3.10/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/PycharmProjects/pythub/.venv/lib/python3.10/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/PycharmProjects/pythub/.venv/lib/python3.10/site-packages/pandas/core/nanops.py:719, in nanmean(values, axis, skipna, mask)
#     716     dtype_count = dtype
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~/PycharmProjects/pythub/.venv/lib/python3.10/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
